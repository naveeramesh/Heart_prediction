# %% [markdown]
# ## Heart disease prediction using SVM

# %%
import numpy as  np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
heart_data=pd.read_csv("heart.csv")
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
X=heart_data.drop(columns='target',axis=1)
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
Y=heart_data['target']
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
##Standardize the data
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standard_data_heart=scaler.transform(X)

# %%
standard_data_heart
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292, ..., -2.27457861,
#         -0.71442887, -2.14887271],
#        [-1.91531289,  0.68100522,  1.00257707, ..., -2.27457861,
#         -0.71442887, -0.51292188],
#        [-1.47415758, -1.46841752,  0.03203122, ...,  0.97635214,
#         -0.71442887, -0.51292188],
#        ...,
#        [ 1.50364073,  0.68100522, -0.93851463, ..., -0.64911323,
#          1.24459328,  1.12302895],
#        [ 0.29046364,  0.68100522, -0.93851463, ..., -0.64911323,
#          0.26508221,  1.12302895],
#        [ 0.29046364, -1.46841752,  0.03203122, ..., -0.64911323,
#          0.26508221, -0.51292188]])

# %%
X=standard_data_heart
Y=heart_data['target']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,stratify=Y,test_size=0.3,random_state=1)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (303, 13) (212, 13) (91, 13)

# %%
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (303,) (212,) (91,)

# %%
classifier=svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction=classifier.predict(X_train)
train_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy score of training model :",train_accuracy)
# Out:
# Accuracy score of training model : 0.8537735849056604

# %%
X_test_prediction=classifier.predict(X_test)
test_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print("Accuracy score of test model :",test_accuracy)
# Out:
# Accuracy score of test model : 0.8461538461538461

# %%
input_data=[61,1,0,140,207,0,0,138,1,1.9,2,1,3]
numpy_array=np.asarray(input_data)
numpy_array
# Out:
# array([ 61. ,   1. ,   0. , 140. , 207. ,   0. ,   0. , 138. ,   1. ,
#          1.9,   2. ,   1. ,   3. ])

# %%
reshaped=numpy_array.reshape(1,-1)

# %%
reshaped
# Out:
# array([[ 61. ,   1. ,   0. , 140. , 207. ,   0. ,   0. , 138. ,   1. ,
#           1.9,   2. ,   1. ,   3. ]])

# %%
standard_array=scaler.transform(reshaped)

# %%
prediction=classifier.predict(standard_array)
print(prediction)
if prediction[0] == 0:
    print("No heart disease")
else:
    print("Have heart ")
# Out:
# [0]
# No heart disease
